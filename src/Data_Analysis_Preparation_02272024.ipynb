# %% [markdown]
# Data Analysis

# %%
import warnings
warnings.filterwarnings("ignore")

import _pickle as cPickle
import pandas as pd
import numpy as np

# %%
cmdty_entire_df = pd.read_csv('commodities_data.csv')
cmdty_entire_df['Date'] = pd.to_datetime(cmdty_entire_df['Date'])
cmdty_entire_df['YearMonth'] = cmdty_entire_df['Date'].dt.to_period('M')
cmdty_entire_df.head()
# Out:
#   Commodity  Contract       Date  PX_LAST YearMonth
# 0    Barley         1 1991-03-25   206.23   1991-03
# 1    Barley         1 1991-03-26   206.02   1991-03
# 2    Barley         1 1991-03-27   205.17   1991-03
# 3    Barley         1 1991-03-28   205.17   1991-03
# 4    Barley         1 1991-04-01   207.29   1991-04

# %%
len((cmdty_entire_df['Commodity']).unique())
# Out:
# 30

# %%
cmdty_entire_df.sort_values(by=['Commodity','Date'])
cmdty_entire_df.fillna(method='ffill', inplace=True)
cmdty_entire_df.head()
# Out:
#   Commodity  Contract       Date  PX_LAST YearMonth
# 0    Barley         1 1991-03-25   206.23   1991-03
# 1    Barley         1 1991-03-26   206.02   1991-03
# 2    Barley         1 1991-03-27   205.17   1991-03
# 3    Barley         1 1991-03-28   205.17   1991-03
# 4    Barley         1 1991-04-01   207.29   1991-04

# %%
cmdty_cntrct_2_df = cmdty_entire_df[cmdty_entire_df['Contract']==2]
cmdty_cntrct_2_df = cmdty_cntrct_2_df.set_index('Date')
cmdty_cntrct_2_df.head()
# Out:
#            Commodity  Contract  PX_LAST YearMonth
# Date
# 1991-03-25    Barley         2   182.45   1991-03
# 1991-03-26    Barley         2   181.86   1991-03
# 1991-03-27    Barley         2   183.44   1991-03
# 1991-03-28    Barley         2   187.38   1991-03
# 1991-04-01    Barley         2   188.96   1991-04

# %% [markdown]
# ## Compute Number of Observations

# %%
monthly_observations = cmdty_entire_df.groupby(['Commodity', 'YearMonth']).size().reset_index(name='Observations')
cmdty_obs_count = cmdty_entire_df.groupby('Commodity')['YearMonth'].nunique().reset_index(name='N')
cmdty_obs_count.head()
# Out:
#    Commodity    N
# 0  Aluminium  116
# 1     Barley  214
# 2   Broilers  103
# 3     Canola  324
# 4       Coal    3

# %% [markdown]
# ## Returns, Volatility, and Sharpe Calculations

# %%
# Get price for Max Date for Each Commodity for Each Month for Contract 2
cmdty_cntrct_2_df = cmdty_cntrct_2_df.reset_index()
max_date_px_last_cntrct_2 = cmdty_cntrct_2_df.groupby(['Commodity', 'YearMonth']).apply(
    lambda x: x.loc[x['Date'].idxmax(), ['Date', 'PX_LAST']]).reset_index()
max_date_px_last_cntrct_2.sort_values(by=['Commodity','YearMonth'], inplace =True)
max_date_px_last_cntrct_2.set_index('Date', inplace=True)
max_date_px_last_cntrct_2.head()
# Out:
#             Commodity YearMonth  PX_LAST
# Date
# 1999-05-28  Aluminium   1999-05    75.68
# 1999-06-30  Aluminium   1999-06    82.36
# 1999-07-30  Aluminium   1999-07    82.42
# 1999-08-31  Aluminium   1999-08    85.56
# 1999-09-30  Aluminium   1999-09    87.55

# %%
max_date_px_last_cntrct_2[max_date_px_last_cntrct_2['Commodity'] == 'Broilers']
# Out:
# Empty DataFrame
# Columns: [Commodity, YearMonth, PX_LAST]
# Index: []

# %%
# Pivoted prices for Contract 2
max_date_px_last_cntrct_2_pivot = max_date_px_last_cntrct_2.pivot_table(index = 'Date', columns = 'Commodity', values = 'PX_LAST')
max_date_px_last_cntrct_2_pivot
# Out:
# Commodity   Aluminium  Barley  Canola   Cocoa  Coffee  Copper       Corn  \
# Date
# 1970-01-30        NaN     NaN     NaN  2527.0     NaN     NaN  2061.8750
# 1970-02-27        NaN     NaN     NaN  2194.0     NaN     NaN  2070.2500
# 1970-03-31        NaN     NaN     NaN  2163.0     NaN     NaN  2066.1250
# 1970-04-30        NaN     NaN     NaN  2095.0     NaN     NaN  2157.9375
# 1970-05-28        NaN     NaN     NaN  1981.0     NaN     NaN  2145.3125
# ...               ...     ...     ...     ...     ...     ...        ...
# 2008-08-29     128.26  248.88  569.19  2875.0  152.87  339.75   623.0000
# 2008-09-30     114.18  196.60  449.92  2569.0  137.93  290.36   522.4375
# 2008-10-31      95.87  187.78  429.60  2070.0  120.48  184.78   432.4375
# 2008-11-28      82.85  155.10  409.90  2281.0  118.60  166.10   377.2500
# 2008-12-31      72.05  163.00  413.60  2657.0  114.30  142.05   417.7500
#
# Commodity   Cotton  Crude Oil  Feeder cattle  ...  Orange juice  Palladium  \
# Date                                          ...
# 1970-01-30   61.78        NaN            NaN  ...        209.01        NaN
# 1970-02-27   61.68        NaN            NaN  ...        162.52        NaN
# 1970-03-31   61.42        NaN            NaN  ...        162.11        NaN
# 1970-04-30   59.58        NaN            NaN  ...        172.42        NaN
# 1970-05-28   60.72        NaN            NaN  ...        153.26        NaN
# ...            ...        ...            ...  ...           ...        ...
# 2008-08-29   74.54     126.21        110.729  ...        121.84     312.94
# 2008-09-30   61.15     109.72        104.152  ...         97.81     206.76
# 2008-10-31   48.06      74.47         98.525  ...         84.45     203.68
# 2008-11-28   47.86      59.51         92.225  ...         78.80     196.25
# 2008-12-31   49.31      48.59         93.675  ...         67.90     189.70
#
# Commodity   Platinum  Propane  Rough rice  Silver  Soybean meal   Soybeans  \
# Date
# 1970-01-30       NaN      NaN         NaN     NaN        107.09   654.3750
# 1970-02-27       NaN      NaN         NaN     NaN        110.16   661.3750
# 1970-03-31       NaN      NaN         NaN     NaN        107.04   660.3750
# 1970-04-30       NaN      NaN         NaN     NaN        111.13   672.3125
# 1970-05-28       NaN      NaN         NaN     NaN        109.25   673.1875
# ...              ...      ...         ...     ...           ...        ...
# 2008-08-29   1513.65   176.47      19.688  13.838        363.08  1359.1250
# 2008-09-30   1038.00   146.04      19.621  12.394        289.04  1076.1875
# 2008-10-31    837.60    94.93      15.595   9.754        275.49   945.2500
# 2008-11-28    888.30    73.88      13.480  10.245        255.40   891.0000
# 2008-12-31    941.50    65.13      15.250  11.307        299.80   980.0000
#
# Commodity   Unleaded gas      Wheat
# Date
# 1970-01-30           NaN   976.4375
# 1970-02-27           NaN  1018.8125
# 1970-03-31           NaN  1003.1875
# 1970-04-30           NaN  1044.5000
# 1970-05-28           NaN   991.8750
# ...                  ...        ...
# 2008-08-29           NaN   845.1250
# 2008-09-30           NaN   718.1250
# 2008-10-31           NaN   570.1250
# 2008-11-28           NaN   574.7500
# 2008-12-31           NaN   623.5000
#
# [494 rows x 28 columns]

# %%
cmdty_cntrct_2_rets_df = max_date_px_last_cntrct_2_pivot.pct_change()

# %%
def Performance_Metrics(df_asset_returns, annualizing_period = 12):
    """
    Input:DataFrame of Returns/Excess Returns
    Output:DataFrame for Summary Statistics: 
                    1. Annualized Mean, 
                    2. Annualized Vol, 
                    3. Annualized Sharpe Ratio
    """
    mean_returns = df_asset_returns.mean() * annualizing_period * 100
    std_returns = df_asset_returns.std() * np.sqrt(annualizing_period) * 100
    sharpe_ratio = mean_returns/std_returns
    performance_metrics = pd.DataFrame({"Annualized Mean Returns": mean_returns, "Annualized Vol": std_returns, "Annualized Sharpe Ratio" : sharpe_ratio})
    return performance_metrics

# %%
cmdty_cntrct_2_perf_metrics_df = Performance_Metrics(cmdty_cntrct_2_rets_df)
cmdty_cntrct_2_perf_metrics_df.head()
# Out:
#            Annualized Mean Returns  Annualized Vol  Annualized Sharpe Ratio
# Commodity
# Aluminium                 1.211298       18.460714                 0.065615
# Barley                    0.991459       18.742002                 0.052900
# Canola                   -0.728509       19.396765                -0.037558
# Cocoa                     4.529431       30.219851                 0.149883
# Coffee                    6.466619       35.995597                 0.179650

# %%
table_1 = pd.merge(cmdty_obs_count, cmdty_cntrct_2_perf_metrics_df, how = 'left',left_on='Commodity', right_on='Commodity')
table_1
# Out:
#         Commodity    N  Annualized Mean Returns  Annualized Vol  \
# 0       Aluminium  116                 1.211298       18.460714
# 1          Barley  214                 0.991459       18.742002
# 2        Broilers  103                      NaN             NaN
# 3          Canola  324                -0.728509       19.396765
# 4            Coal    3                      NaN             NaN
# 5           Cocoa  468                 4.529431       30.219851
# 6          Coffee  437                 6.466619       35.995597
# 7          Copper  241                 8.956501       24.984615
# 8            Corn  468                -1.097886       24.113173
# 9          Cotton  468                 2.073381       23.198005
# 10      Crude Oil  310                12.573607       32.452474
# 11  Feeder cattle  445                 3.553580       16.039977
# 12       Gasoline   39               -11.348232       40.518210
# 13           Gold  408                 0.276342       19.120845
# 14    Heating Oil  273                12.376028       31.911915
# 15      Lean hogs  273                 5.833266       20.964350
# 16    Live cattle  468                 5.532987       15.825944
# 17         Lumber  273                 3.718321       24.919404
# 18    Natural gas  225                 2.273954       49.436177
# 19           Oats  468                 0.063138       29.594868
# 20   Orange juice  468                 1.557579       30.567180
# 21      Palladium  273                 7.008087       30.609663
# 22       Platinum  273                 5.680173       21.563120
# 23        Propane  241                23.063076       47.206180
# 24     Rough rice  240                -1.236726       25.606212
# 25         Silver  408                 1.564841       30.825857
# 26   Soybean meal  468                 6.826445       30.743190
# 27       Soybeans  468                 4.535501       27.445748
# 28   Unleaded gas  248                 9.970972       29.292918
# 29          Wheat  468                 1.755957       24.204356
#
#     Annualized Sharpe Ratio
# 0                  0.065615
# 1                  0.052900
# 2                       NaN
# 3                 -0.037558
# 4                       NaN
# 5                  0.149883
# 6                  0.179650
# 7                  0.358481
# 8                 -0.045531
# 9                  0.089378
# 10                 0.387447
# 11                 0.221545
# 12                -0.280077
# 13                 0.014452
# 14                 0.387818
# 15                 0.278247
# 16                 0.349615
# 17                 0.149214
# 18                 0.045998
# 19                 0.002133
# 20                 0.050956
# 21                 0.228950
# 22                 0.263421
# 23                 0.488561
# 24                -0.048298
# 25                 0.050764
# 26                 0.222047
# 27                 0.165253
# 28                 0.340388
# 29                 0.072547

# %% [markdown]
# ## Basis Calculation

# %%
max_contract_px_last = cmdty_entire_df.groupby(['Commodity','YearMonth']).apply(
    lambda x: x.loc[x['Contract'].idxmax()]).reset_index(drop=True)
max_contract_px_last = max_contract_px_last[max_contract_px_last['Contract'] > 2]
max_contract_px_last.sort_values(by=['Commodity', 'YearMonth'], inplace=True)
max_contract_px_last.set_index('Date', inplace=True)
max_contract_px_last
# Out:
#             Commodity  Contract  PX_LAST YearMonth
# Date
# 1999-05-18  Aluminium         4    33.33   1999-05
# 1999-06-01  Aluminium         4    31.65   1999-06
# 1999-07-01  Aluminium         4    34.25   1999-07
# 1999-08-02  Aluminium         4    33.93   1999-08
# 1999-09-01  Aluminium         4    36.18   1999-09
# ...               ...       ...      ...       ...
# 2008-08-01      Wheat        10   904.00   2008-08
# 2008-09-02      Wheat        11   888.75   2008-09
# 2008-10-01      Wheat        11   787.75   2008-10
# 2008-11-03      Wheat        11   683.75   2008-11
# 2008-12-01      Wheat        10   631.75   2008-12
#
# [9314 rows x 4 columns]

# %%
# max_contract_px_last_pivot = max_contract_px_last.pivot_table(index = 'Date', columns = ['Commodity','Contract'], values = 'PX_LAST')
# max_contract_px_last_pivot.fillna(method='ffill', inplace=True)
# max_contract_px_last_pivot

# %%
max_date_px_last_cntrct_2.reset_index(inplace=True)
max_contract_px_last.reset_index(inplace=True)
cmdtry_cntrct_2_and_latest_df = pd.merge(max_date_px_last_cntrct_2, max_contract_px_last, how='left', left_on=['Commodity', 'YearMonth'], right_on=['Commodity', 'YearMonth'])
cmdtry_cntrct_2_and_latest_df
# Out:
#          Date_x  Commodity YearMonth  PX_LAST_x   index     Date_y  Contract  \
# 0    1999-05-28  Aluminium   1999-05     75.680     0.0 1999-05-18       4.0
# 1    1999-06-30  Aluminium   1999-06     82.360     1.0 1999-06-01       4.0
# 2    1999-07-30  Aluminium   1999-07     82.420     2.0 1999-07-01       4.0
# 3    1999-08-31  Aluminium   1999-08     85.560     3.0 1999-08-02       4.0
# 4    1999-09-30  Aluminium   1999-09     87.550     4.0 1999-09-01       4.0
# ...         ...        ...       ...        ...     ...        ...       ...
# 9447 2008-08-29      Wheat   2008-08    845.125  9309.0 2008-08-01      10.0
# 9448 2008-09-30      Wheat   2008-09    718.125  9310.0 2008-09-02      11.0
# 9449 2008-10-31      Wheat   2008-10    570.125  9311.0 2008-10-01      11.0
# 9450 2008-11-28      Wheat   2008-11    574.750  9312.0 2008-11-03      11.0
# 9451 2008-12-31      Wheat   2008-12    623.500  9313.0 2008-12-01      10.0
#
#       PX_LAST_y
# 0         33.33
# 1         31.65
# 2         34.25
# 3         33.93
# 4         36.18
# ...         ...
# 9447     904.00
# 9448     888.75
# 9449     787.75
# 9450     683.75
# 9451     631.75
#
# [9452 rows x 8 columns]

# %%
cmdtry_cntrct_2_and_latest_df['Contract_Base_Num'] = 2
cmdtry_cntrct_2_and_latest_df
# Out:
#          Date_x  Commodity YearMonth  PX_LAST_x   index     Date_y  Contract  \
# 0    1999-05-28  Aluminium   1999-05     75.680     0.0 1999-05-18       4.0
# 1    1999-06-30  Aluminium   1999-06     82.360     1.0 1999-06-01       4.0
# 2    1999-07-30  Aluminium   1999-07     82.420     2.0 1999-07-01       4.0
# 3    1999-08-31  Aluminium   1999-08     85.560     3.0 1999-08-02       4.0
# 4    1999-09-30  Aluminium   1999-09     87.550     4.0 1999-09-01       4.0
# ...         ...        ...       ...        ...     ...        ...       ...
# 9447 2008-08-29      Wheat   2008-08    845.125  9309.0 2008-08-01      10.0
# 9448 2008-09-30      Wheat   2008-09    718.125  9310.0 2008-09-02      11.0
# 9449 2008-10-31      Wheat   2008-10    570.125  9311.0 2008-10-01      11.0
# 9450 2008-11-28      Wheat   2008-11    574.750  9312.0 2008-11-03      11.0
# 9451 2008-12-31      Wheat   2008-12    623.500  9313.0 2008-12-01      10.0
#
#       PX_LAST_y  Contract_Base_Num
# 0         33.33                  2
# 1         31.65                  2
# 2         34.25                  2
# 3         33.93                  2
# 4         36.18                  2
# ...         ...                ...
# 9447     904.00                  2
# 9448     888.75                  2
# 9449     787.75                  2
# 9450     683.75                  2
# 9451     631.75                  2
#
# [9452 rows x 9 columns]

# %%
print(len(max_date_px_last_cntrct_2),len(max_contract_px_last))
# Out:
# 9452 9314
